# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('Happiness_Survey_students_Goldsmiths.csv', usecols= range(1,15))
df = pd.read_csv('Happiness_Survey_students_Goldsmiths.csv')
df = df.dropna().drop('時間戳記', axis=1)

df.head().append(df.tail())
# Out:
#    I agree that people in my life care about me.  \
# 0                                          Agree
# 1                                          Agree
# 2                                          Agree
# 3                                          Agree
# 4                                          Agree
# 31                                         Agree
# 32                                         Agree
# 33                                         Agree
# 34                     Neither agree or disagree
# 35                                      Disagree
#
#    How much of the time have I felt lonely during the past week?  \
# 0                                              Rarely
# 1                                               Often
# 2                                              Rarely
# 3                                Very rarely or never
# 4                                               Often
# 31                                              Often
# 32                                          Sometimes
# 33                                             Rarely
# 34                                              Often
# 35                               Very often or always
#
#    My friends make me feel happy.  \
# 0                       Sometimes
# 1                           Often
# 2            Very often or always
# 3            Very often or always
# 4            Very often or always
# 31                          Often
# 32                          Often
# 33                          Often
# 34                      Sometimes
# 35                         Rarely
#
#    How often do I share my feelings with friends or relatives?  \
# 0                                Once or twice a week
# 1                                    About once a day
# 2                               Once or twice a month
# 3                          Three times a week or more
# 4                               Once or twice a month
# 31                         Three times a week or more
# 32                         Three times a week or more
# 33                         Three times a week or more
# 34                               Once or twice a week
# 35                                              Never
#
#    How much time do I feel hopeful about my future in my study/programme?  \
# 0                                               Often
# 1                                           Sometimes
# 2                                Very often or always
# 3                                           Sometimes
# 4                                           Sometimes
# 31                                              Often
# 32                                          Sometimes
# 33                                              Often
# 34                                              Often
# 35                                          Sometimes
#
#    How would I rate my study-life balance?  \
# 0                            Somewhat poor
# 1                            Somewhat poor
# 2                                  Neutral
# 3                         Somewhat balance
# 4                            Somewhat poor
# 31                           Somewhat poor
# 32                           Somewhat poor
# 33                        Somewhat balance
# 34                                 Neutral
# 35                           Somewhat poor
#
#    No matter what life throws at me, I believe that I can deal with it.  \
# 0                                      Strongly agree
# 1                                               Agree
# 2                           Neither agree or disagree
# 3                                      Strongly agree
# 4                                               Agree
# 31                          Neither agree or disagree
# 32                                              Agree
# 33                                              Agree
# 34                          Neither agree or disagree
# 35                          Neither agree or disagree
#
#    I believe that what can go wrong will go wrong.  \
# 0                                         Disagree
# 1                                         Disagree
# 2                        Neither agree or disagree
# 3                        Neither agree or disagree
# 4                        Neither agree or disagree
# 31                                  Strongly agree
# 32                       Neither agree or disagree
# 33                                        Disagree
# 34                                        Disagree
# 35                       Neither agree or disagree
#
#    I think the school provides good teaching systems.  \
# 0                                               Agree
# 1                                               Agree
# 2                           Neither agree or disagree
# 3                                               Agree
# 4                                               Agree
# 31                                           Disagree
# 32                          Neither agree or disagree
# 33                          Neither agree or disagree
# 34                                              Agree
# 35                          Neither agree or disagree
#
#    I enjoy my school life and the school’s facilities.  \
# 0                           Neither agree or disagree
# 1                           Neither agree or disagree
# 2                                               Agree
# 3                                               Agree
# 4                                               Agree
# 31                          Neither agree or disagree
# 32                                              Agree
# 33                                              Agree
# 34                                              Agree
# 35                                           Disagree
#
#    How many times in the past week have I been in good spirits?  \
# 0                                              Rarely
# 1                                               Often
# 2                                               Often
# 3                                           Sometimes
# 4                                           Sometimes
# 31                                              Often
# 32                                          Sometimes
# 33                                          Sometimes
# 34                                          Sometimes
# 35                                             Rarely
#
#    I am satisfied with my ability to perform activities of daily living.  \
# 0                                           Satisfied
# 1                  Neither satisfied nor dissatisfied
# 2                                           Satisfied
# 3                                           Satisfied
# 4                                   Very dissatisfied
# 31                 Neither satisfied nor dissatisfied
# 32                                       Dissatisfied
# 33                 Neither satisfied nor dissatisfied
# 34                                       Dissatisfied
# 35                                       Dissatisfied
#
#    I have enough money to buy things I want.  \
# 0                                      Agree
# 1                          Strongly disagree
# 2                                      Agree
# 3                                   Disagree
# 4                             Strongly agree
# 31                                  Disagree
# 32                                     Agree
# 33                 Neither agree or disagree
# 34                                  Disagree
# 35                                  Disagree
#
#    In general, how much stress do I have with my personal finances?  \
# 0                                     Moderate stress
# 1                                         High stress
# 2                                     Moderate stress
# 3                                          Low stress
# 4                                     Moderate stress
# 31                                    Moderate stress
# 32                                    Moderate stress
# 33                                    Moderate stress
# 34                                        High stress
# 35                                        High stress
#
#    My age is… I am from… (Country/ Region) My gender is… I am studying in…  \
# 0     Over 32                       Taiwan        Female   Master’s Degree
# 1       23–27                       Taiwan        Female   Master’s Degree
# 2       23–27                        India        Female   Master’s Degree
# 3       28–32                       Taiwan        Female   Master’s Degree
# 4       23–27                        India        Female   Master’s Degree
# 31      23–27                        china          Male   Master’s Degree
# 32      28–32                       Taiwan        Female   Master’s Degree
# 33      18–22                        China          Male   Master’s Degree
# 34      23–27                        India        Female   Master’s Degree
# 35      23–27                        Sorry          Male   Master’s Degree
#
#                The department where I am studying is
# 0                                         A/Computing
# 1                                               A/Art
# 2                                         A/Computing
# 3   A/Institute of Creative and Cultural Entrepren...
# 4                                             A/Stacs
# 31                                        A/Computing
# 32                                        A/Computing
# 33                                        A/Computing
# 34                                        A/Computing
# 35                                        A/Computing

# %%
ax1 = df[df['My gender is…'] == 'Female']['I agree that people in my life care about me.'].value_counts()
ax2 = df[df['My gender is…'] == 'Male']['I agree that people in my life care about me.'].value_counts()
ax3 = df[df['My gender is…'] == 'Prefer not to say']['I agree that people in my life care about me.'].value_counts()
dfa = pd.concat([ax1,ax2,ax3],axis=1).fillna(0)
dfa.columns = ['Female', 'Male', 'Prefer not to say']

fig, axs = plt.subplots(1,3, figsize=(20, 10))
axs[0].pie(
        ax1,
        labels=['Strongly agree', 'Agree', 'Neither agree or disagree', 'Disagree'],
        autopct='%1.1f%%',
        startangle=270,
        radius=1,
        counterclock=False)
axs[0].set_title('Female')
axs[1].pie(
        ax2,
        labels=['Strongly agree', 'Agree', 'Neither agree or disagree'],
        autopct='%1.1f%%',
        startangle=270,
        radius=1,
        counterclock=False)
axs[1].set_title('Male')
axs[2].pie(
        ax3,
        labels=['Strongly agree'],
        autopct='%1.1f%%',
        startangle=270,
        radius=1,
        counterclock=False)
axs[2].set_title('Prefer not to say')
fig.suptitle("I agree that people in my life care about me.",y=0.8);

plt.show()
# Out:
# Agree                        16
# Strongly agree                5
# Neither agree or disagree     4
# Disagree                      1
# Name: I agree that people in my life care about me., dtype: int64

# %%
ax1 = df[df['My gender is…'] == 'Female']['I agree that people in my life care about me.'].value_counts()
ax2 = df[df['My gender is…'] == 'Male']['I agree that people in my life care about me.'].value_counts()
ax3 = df[df['My gender is…'] == 'Prefer not to say']['I agree that people in my life care about me.'].value_counts()
dfa = pd.concat([ax1,ax2,ax3],axis=1).fillna(0)
dfa.columns = ['Female', 'Male', 'Prefer not to say']
dfa = dfa.transpose()
print(dfa)

fig, ax = plt.subplots(figsize=(10,7))
ax = dfa.plot.bar(rot=20,  ax=ax)
ax.set_xlabel('I agree that people in my life care about me.')
ax.set_ylabel('number of people')
ax.legend(fontsize = 12)

plt.show()
# Out:
#                    Agree  Strongly agree  Neither agree or disagree  Disagree
# Female              16.0             5.0                        4.0       1.0
# Male                 6.0             2.0                        0.0       1.0
# Prefer not to say    0.0             1.0                        0.0       0.0

# %%
ax1 = df[df['The department where I am studying is '] == 'A/Computing']['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
ax2 = df[df['The department where I am studying is '] == 'A/Media, Communications and Cultural Studies']['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
ax3 = df[df['The department where I am studying is '] == 'A/Institute of Creative and Cultural Entrepreneurship']['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
ax4 = df[df['The department where I am studying is '] == 'A/Art']['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
ax5 = df[df['The department where I am studying is '] == 'A/Stacs']['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
dfa = pd.concat([ax1,ax2,ax3,ax4,ax5],axis=1).fillna(0)
dfa.columns = ['A/Computing', 'A/Media', 'A/Institute of CCE', 'A/Art', 'A/Stacs']

dfa = dfa.transpose()

fig, ax = plt.subplots(figsize=(10,7))
dfa.plot.barh(stacked=True, rot=0, ax=ax)
ax.invert_yaxis()
fig.suptitle("How would I rate my study-life balance?",y=0.95);
ax.set_xlabel('Percentage of people')
ax.set_ylabel('Student departments')
ax.legend(bbox_to_anchor=(1,1), fontsize = 12)
plt.show()

# %%
ax1 = df[df['My gender is…'] == 'Female']['I have enough money to buy things I want.'].value_counts(normalize=True)
ax2 = df[df['My gender is…'] == 'Male']['I have enough money to buy things I want.'].value_counts(normalize=True)
ax3 = df[df['My gender is…'] == 'Prefer not to say']['I have enough money to buy things I want.'].value_counts(normalize=True)
dfa = pd.concat([ax1,ax2,ax3],axis=1).fillna(0)
dfa.columns = ['Female', 'Male', 'Prefer not to say']
dfa = dfa.transpose()

fig, ax = plt.subplots(figsize=(10,7))
dfa.plot.barh(stacked=True, rot=0, ax=ax)
ax.invert_yaxis()
fig.suptitle("I have enough money to buy things I want.",y=0.95);
ax.set_xlabel('Percentage of people')
ax.set_ylabel('Genders')
ax.legend(bbox_to_anchor=(1,1), fontsize = 12)
plt.show()

# %%
ax1 = df[df['My gender is…'] == 'Female']['How often do I share my feelings with friends or relatives?'].value_counts(normalize=True)
ax2 = df[df['My gender is…'] == 'Male']['How often do I share my feelings with friends or relatives?'].value_counts(normalize=True)
ax3 = df[df['My gender is…'] == 'Prefer not to say']['How often do I share my feelings with friends or relatives?'].value_counts(normalize=True)
dfa = pd.concat([ax1,ax2,ax3],axis=1).fillna(0)
dfa.columns = ['Female', 'Male', 'Prefer not to say']
dfa = dfa.transpose()

fig, ax = plt.subplots(figsize=(10,7))
dfa.plot.barh(stacked=True, rot=0, ax=ax)
ax.invert_yaxis()
fig.suptitle("How often do I share my feelings with friends or relatives?",y=0.95);
ax.set_xlabel('Percentage of people')
ax.set_ylabel('Genders')
ax.legend(bbox_to_anchor=(1,1), fontsize = 12)
plt.show()

# %%
dfs = df['My friends make me feel happy.'].value_counts()
print(dfs)
ax = dfs.plot.barh()
ax.invert_yaxis()
ax.set_xlabel('people number')
ax.set_ylabel('answer')
ax.set_xlim(0,20)
ax.set_title('My friends make me feel happy.')
# Out:
# Often                   18
# Sometimes                8
# Very often or always     8
# Rarely                   2
# Name: My friends make me feel happy., dtype: int64
# Text(0.5, 1.0, 'My friends make me feel happy.')

# %%
dfs = df['In general, how much stress do I have with my personal finances?'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='In general, how much stress do I have with my personal finances?',
        subplots=True)
# Out:
# Moderate stress        0.583
# High stress            0.222
# Low stress             0.111
# Overwhelming stress    0.056
# No stress at all       0.028
# Name: In general, how much stress do I have with my personal finances?, dtype: float64

# %%
dfs = df['I am satisfied with my ability to perform activities of daily living.'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='I am satisfied with my ability to perform activities of daily living.',
        subplots=True)
# Out:
# Satisfied                             0.417
# Neither satisfied nor dissatisfied    0.306
# Dissatisfied                          0.222
# Very satisfied                        0.028
# Very dissatisfied                     0.028
# Name: I am satisfied with my ability to perform activities of daily living., dtype: float64

# %%
dfs = df['I think the school provides good teaching systems.'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='I think the school provides good teaching systems.',
        subplots=True)
# Out:
# Agree                        0.444
# Neither agree or disagree    0.417
# Strongly agree               0.083
# Disagree                     0.056
# Name: I think the school provides good teaching systems., dtype: float64

# %%
dfs = df['No matter what life throws at me, I believe that I can deal with it.'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='No matter what life throws at me, I believe that I can deal with it.',
        subplots=True)
# Out:
# Agree                        0.444
# Neither agree or disagree    0.250
# Disagree                     0.167
# Strongly agree               0.111
# Strongly disagree            0.028
# Name: No matter what life throws at me, I believe that I can deal with it., dtype: float64

# %%
dfs = df['How would I rate my study-life balance?'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='How would I rate my study-life balance?',
        subplots=True)
# Out:
# Somewhat poor       0.389
# Neutral             0.222
# Somewhat balance    0.222
# Very poor           0.111
# Very balance        0.056
# Name: How would I rate my study-life balance?, dtype: float64

# %%
dfs = df['How much time do I feel hopeful about my future in my study/programme?'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='How much time do I feel hopeful about my future in my study/programme?',
        subplots=True)
# Out:
# Sometimes               0.528
# Often                   0.306
# Very often or always    0.111
# Rarely                  0.056
# Name: How much time do I feel hopeful about my future in my study/programme?, dtype: float64

# %%
dfs = df['My friends make me feel happy.'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='My friends make me feel happy.',
        subplots=True)
# Out:
# Often                   0.500
# Sometimes               0.222
# Very often or always    0.222
# Rarely                  0.056
# Name: My friends make me feel happy., dtype: float64

# %%
dfs = df['How much of the time have I felt lonely during the past week?'].value_counts(normalize=True).round(3)
print(dfs)
ax = dfs.plot.pie(
        autopct='%1.1f%%',
        startangle=270,
        counterclock=False,
        label='',
        title='How much of the time have I felt lonely during the past week?',
        subplots=True)
# Out:
# Sometimes               0.306
# Often                   0.278
# Rarely                  0.222
# Very rarely or never    0.111
# Very often or always    0.083
# Name: How much of the time have I felt lonely during the past week?, dtype: float64
